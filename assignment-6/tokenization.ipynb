# %%
text = "Hey this is Sreeganesh Jasti , I am learning Agentic AI and I am currently in the second year of BTech."

# %%
text.split()
# Out:
# ['Hey',
#  'this',
#  'is',
#  'Sreeganesh',
#  'Jasti',
#  ',',
#  'I',
#  'am',
#  'learning',
#  'Agentic',
#  'AI',
#  'and',
#  'I',
#  'am',
#  'currently',
#  'in',
#  'the',
#  'second',
#  'year',
#  'of',
#  'BTech.']

# %%
from nltk import sent_tokenize,word_tokenize

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
sent_tokens = sent_tokenize(text)
sent_tokens
# Out:
# ['Hey this is Sreeganesh Jasti , I am learning Agentic AI and I am currently in the second year of BTech.']

# %%
word_tokens = word_tokenize(text)
word_tokens
# Out:
# ['Hey',
#  'this',
#  'is',
#  'Sreeganesh',
#  'Jasti',
#  ',',
#  'I',
#  'am',
#  'learning',
#  'Agentic',
#  'AI',
#  'and',
#  'I',
#  'am',
#  'currently',
#  'in',
#  'the',
#  'second',
#  'year',
#  'of',
#  'BTech',
#  '.']
